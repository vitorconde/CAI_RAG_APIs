# %%
import requests
import pandas as pd
import json

# %%
url = "https://apps.spaguas.sp.gov.br/sibh/api/v2/measurements/now"

params = {
    "station_type_id": 1,
    "hours": 1,              # 1 até 72
    "show_all": "false",     # true ou false
    "serializer": "complete",# complete ou simplify
    "public": "true"         # true ou false
}

response = requests.get(url, params=params, timeout=30)
response.raise_for_status()

data = response.json()

# %%
# transforma a lista de medições em DataFrame
df = pd.json_normalize(data["measurements"])

print(df.head())
print(df.columns.tolist())
# Out:
#   station_prefix_id   prefix  \
# 0                 2  1000874
# 1                 4      179
# 2                 6      619
# 3                 8      193
# 4                10  1001177
#
#                                         station_name station_type_id city_id  \
# 0                         Vargem (Barragem Jaguari)                1      62
# 1                      Joanópolis (Barragem Jacareí)               1     430
# 2  Joanópolis (Barragem Jacareí - Túnel 7 / Vargem)                1     430
# 3           Extrema (F25B - Rio Jaguari - Divisa SP)               1     649
# 4                      Piracaia (Barragem Cachoeira)               1     518
#
#          city cod_ibge             latitude           longitude station_owner  \
# 0      Vargem  3556354             -22.9223            -46.4223        SABESP
# 1  Joanópolis  3525508  -22.971511804003057  -46.33003234863282        SABESP
# 2  Joanópolis  3525508   -22.97240908618847  -46.32962800380204        SABESP
# 3     Extrema  3125101             -22.8668            -46.3588        SABESP
# 4    Piracaia  3538600   -23.05073765758915  -46.31929814815521        SABESP
#
#    ... param_type measurement_classification_type_id  public qtd  \
# 0  ...       None                                  3    True   6
# 1  ...       None                                  3    True   6
# 2  ...       None                                  3    True   6
# 3  ...       None                                  3    True   6
# 4  ...       None                                  3    True   6
#
#           value  read_value max_value  min_value                  min_date  \
# 0  83245.633333         NaN   83245.8    83245.3  2026-03-19T12:40:00.000Z
# 1  83246.700000         NaN   83246.9    83246.4  2026-03-19T12:40:00.000Z
# 2  83237.783333         NaN   83238.1    83237.5  2026-03-19T12:40:00.000Z
# 3    240.333333   31.070667     241.5      239.2  2026-03-19T12:40:00.000Z
# 4  81927.800000         NaN   81927.9    81927.7  2026-03-19T12:40:00.000Z
#
#                    max_date
# 0  2026-03-19T13:30:00.000Z
# 1  2026-03-19T13:30:00.000Z
# 2  2026-03-19T13:30:00.000Z
# 3  2026-03-19T13:30:00.000Z
# 4  2026-03-19T13:30:00.000Z
#
# [5 rows x 28 columns]
# ['station_prefix_id', 'prefix', 'station_name', 'station_type_id', 'city_id', 'city', 'cod_ibge', 'latitude', 'longitude', 'station_owner', 'ugrhi_id', 'ugrhi_name', 'ugrhi_cod', 'subugrhi_name', 'subugrhi_id', 'subugrhi_cod', 'transmission_type_name', 'measurement_gap', 'param_type', 'measurement_classification_type_id', 'public', 'qtd', 'value', 'read_value', 'max_value', 'min_value', 'min_date', 'max_date']

# %%
# salva o JSON completo
with open("dados_chuva.json", "w", encoding="utf-8") as f:
    json.dump(data, f, ensure_ascii=False, indent=2)

print("Arquivo salvo: dados_chuva.json")
# Out:
# Arquivo salvo: dados_chuva.json

# %%
# ----------------------------
# 1) Quantidade de registros
# ----------------------------
num_registros = len(data.get("measurements", []))

print(f"Quantidade de registros: {num_registros}")

# ----------------------------
# 2) Tamanho do JSON (bytes)
# ----------------------------
json_bytes = response.content
size_bytes = len(json_bytes)
size_kb = size_bytes / 1024
size_mb = size_kb / 1024

print(f"Tamanho do JSON:")
print(f"- {size_bytes} bytes")
print(f"- {size_kb:.2f} KB")
print(f"- {size_mb:.4f} MB")
# Out:
# Quantidade de registros: 479
# Tamanho do JSON:
# - 334141 bytes
# - 326.31 KB
# - 0.3187 MB
